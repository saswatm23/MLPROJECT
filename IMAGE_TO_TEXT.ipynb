# %% [markdown]
# <a href="https://colab.research.google.com/github/saswatm23/MLPROJECT/blob/main/IMAGE_TO_TEXT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras_ocr
import matplotlib.pyplot as plt

# %%
# !pip install -q keras-ocr
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 1.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 69.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 813.9/813.9 kB 58.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 6.7 MB/s eta 0:00:00

# %%
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# ...
# Looking for /root/.keras-ocr/crnn_kurapan.h5
# ...

# %%
images = [
    keras_ocr.tools.read(img) for img in ['myimg.jpg', 'capture.JPG'
    ]
]

# %%
images
# Out:
# [array([[[ 70,  50,  41],
#          [ 68,  48,  39],
#          [ 68,  48,  39],
#          ...,
#          [107, 105,  93],
#          [107, 105,  93],
#          [107, 105,  93]],
#
#         [[ 70,  50,  41],
#          [ 69,  49,  40],
#          [ 69,  49,  40],
#          ...,
#          [107, 105,  93],
#          [107, 105,  93],
#          [107, 105,  93]],
#
#         [[ 71,  51,  42],
#          [ 70,  50,  41],
#          [ 71,  51,  42],
#          ...,
#          [107, 105,  93],
#          [107, 105,  93],
#          [107, 105,  93]],
#
#         ...,
#
#         [[ 22,  22,  22],
#          [ 22,  22,  22],
#          [ 22,  22,  22],
#          ...,
#          [138, 112,  87],
#          [142, 112,  88],
#          [142, 112,  88]],
#
#         [[ 22,  22,  22],
#          [ 22,  22,  22],
#          [ 22,  22,  22],
#          ...,
#          [138, 112,  87],
#          [141, 111,  87],
#          [141, 111,  87]],
#
#         [[ 22,  22,  22],
# ...

# %%
plt.figure(figsize = (10,20))
plt.imshow(images[0])


plt.figure(figsize = (10,20))
plt.imshow(images[1])

# %%
prediction_groups = pipeline.recognize(images)
# Out:
# ...
# 6/6 [==============================] - 5s 142ms/step

# %%
fig, axs = plt.subplots(nrows=len(images), figsize=(10, 20))
for ax, image, predictions in zip(axs, images, prediction_groups):
    keras_ocr.tools.drawAnnotations(image=image,
                                    predictions=predictions,
                                    ax=ax)
